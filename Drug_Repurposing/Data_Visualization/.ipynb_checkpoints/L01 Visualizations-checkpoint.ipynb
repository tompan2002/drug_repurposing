# %% [markdown]
# # L01 PCA + t-SNE

# %% [markdown]
# Principle Component Analysis and t-SNE attempts to visualize separability of data.

# %%
import pandas as pd
import numpy as np
from cmapPy.pandasGEXpress.parse import parse
import time
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Importing data

# %%
gene_info = pd.read_csv("../L01_Antimetabolites_Analysis/geneinfo_beta.txt", sep = "\t", dtype = str)
# landmark_ids = gene_info["gene_id"][gene_info["feature_space"] == "landmark"]

L01_gctoo = parse("../L01_Antimetabolites_Analysis/L01_gctoo.gctx")

df = L01_gctoo.data_df
df = df.T
df_copy = df.copy()
df
# Out:
# rid                                           10       100      1000  \
# cid
# ABY001_A375_XH:BRD-K19687926:0.625:24  -0.228962 -0.331568 -0.229186
# ABY001_A375_XH:BRD-K19687926:0.625:3   -0.669595 -0.384668  0.674206
# ABY001_A375_XH:BRD-K19687926:10:24      1.244192  0.540987 -0.331108
# ABY001_A375_XH:BRD-K19687926:10:3       0.259463  0.050904  1.141743
# ABY001_A375_XH:BRD-K19687926:2.5:24     0.429207 -0.633371 -0.633066
# ...                                          ...       ...       ...
# TSAI001_APP11NPC1_XH:BRD-K81418486:2.5  1.064952  1.057685 -0.423703
# TSAI001_ND347327_XH:BRD-K81418486:2.5   0.346960  1.700166 -1.116897
# TSAI001_SAD11NPC4_XH:BRD-K81418486:2.5  1.643360  1.448630 -3.266874
# TSAI001_SAD21NPC2_XH:BRD-K81418486:2.5  1.480882  1.908292 -2.041822
# TSAI001_SB1NPC3_XH:BRD-K81418486:2.5   -0.050354  0.183900 -1.234355
#
# rid                                        10000     10001     10003  \
# cid
# ABY001_A375_XH:BRD-K19687926:0.625:24   0.196661  0.048434 -0.215881
# ABY001_A375_XH:BRD-K19687926:0.625:3   -0.910629 -0.139324  0.664474
# ABY001_A375_XH:BRD-K19687926:10:24     -1.019858 -1.025045  1.120752
# ABY001_A375_XH:BRD-K19687926:10:3       0.416739 -0.251734 -0.697146
# ABY001_A375_XH:BRD-K19687926:2.5:24    -0.246884  0.368670  0.063852
# ...                                          ...       ...       ...
# TSAI001_APP11NPC1_XH:BRD-K81418486:2.5 -0.182850 -0.587905  0.059945
# TSAI001_ND347327_XH:BRD-K81418486:2.5   0.135789  0.686745  0.705168
# TSAI001_SAD11NPC4_XH:BRD-K81418486:2.5 -0.754537 -0.495905  0.266581
# TSAI001_SAD21NPC2_XH:BRD-K81418486:2.5  0.196110  0.113445 -0.010518
# TSAI001_SB1NPC3_XH:BRD-K81418486:2.5   -0.767452  0.037302  1.607037
#
# rid                                        10004     10005     10006  \
# cid
# ABY001_A375_XH:BRD-K19687926:0.625:24   0.113454 -0.108889 -1.175369
# ABY001_A375_XH:BRD-K19687926:0.625:3    0.207748 -0.256744  0.029963
# ABY001_A375_XH:BRD-K19687926:10:24      0.136119 -0.724501 -0.497458
# ABY001_A375_XH:BRD-K19687926:10:3       0.190578  1.203859 -0.220841
# ABY001_A375_XH:BRD-K19687926:2.5:24    -0.557765  0.247735 -0.287608
# ABY001_A375_XH:BRD-K19687926:2.5:24     0.247222  0.144395 -0.259588
# ...                                          ...       ...       ...
# TSAI001_APP11NPC1_XH:BRD-K81418486:2.5 -0.111424 -1.022690  0.284769
# TSAI001_ND347327_XH:BRD-K81418486:2.5   0.832777 -0.057116  2.643188
# TSAI001_SAD11NPC4_XH:BRD-K81418486:2.5  1.749439  0.003931  2.086139
# TSAI001_SAD21NPC2_XH:BRD-K81418486:2.5  0.595201 -1.343776  0.810295
# TSAI001_SB1NPC3_XH:BRD-K81418486:2.5    0.640389 -0.747843  0.824701
#
# rid                                         9993      9997
# cid
# ABY001_A375_XH:BRD-K19687926:0.625:24   0.028759 -0.322390
# ABY001_A375_XH:BRD-K19687926:0.625:3   -0.898071  0.782295
# ABY001_A375_XH:BRD-K19687926:10:24      0.854950  0.956701
# ABY001_A375_XH:BRD-K19687926:10:3      -0.841701 -0.955335
# ABY001_A375_XH:BRD-K19687926:2.5:24     0.665813 -0.463818
# ...                                          ...       ...
# TSAI001_APP11NPC1_XH:BRD-K81418486:2.5  0.843523  0.864853
# TSAI001_ND347327_XH:BRD-K81418486:2.5   2.205498 -0.678847
# TSAI001_SAD11NPC4_XH:BRD-K81418486:2.5  0.904077  0.585351
# TSAI001_SAD21NPC2_XH:BRD-K81418486:2.5  0.868299 -0.019044
# TSAI001_SB1NPC3_XH:BRD-K81418486:2.5    0.770994  0.013665
#
# [50880 rows x 12328 columns]

# %%
is_of_interest_array = np.loadtxt("../L01_Antimetabolites_Analysis/ANTIMETABOLITES.csv", delimiter = ",")
is_of_interest_array
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %% [markdown]
# ## PCA

# %%
from sklearn.decomposition import PCA
c02_PCA = PCA(n_components = 3)

# %%
components = c02_PCA.fit(df).components_
components = pd.DataFrame(components).transpose()
components.columns = ['Comp1', 'Comp2', "Comp3"]
components.index = df.columns
print(components)
# Out:
#           Comp1     Comp2     Comp3
# rid
# 10     0.011135 -0.003583 -0.005689
# 100    0.004379  0.009443 -0.001265
# 1000  -0.007370 -0.000052  0.002417
# 10000  0.005085 -0.006655 -0.004671
# 10001 -0.004777  0.004832  0.021893
# ...         ...       ...       ...
# 9990   0.013797  0.002388  0.013250
# 9991  -0.005294 -0.007493  0.013489
# 9992   0.014912 -0.009819 -0.002316
# 9993   0.010225  0.008527 -0.009230
# 9997   0.001994 -0.004231 -0.005731
#
# [12328 rows x 3 columns]

# %%
var_ratio = c02_PCA.explained_variance_ratio_
var_ratio_transposed = pd.DataFrame(var_ratio).transpose()
var_ratio_transposed.columns = ['Comp1', 'Comp2', "Comp3"]
var_ratio_transposed.index = ['Proportion of Variance']
print(var_ratio_transposed)
# Out:
#                           Comp1     Comp2     Comp3
# Proportion of Variance  0.26842  0.053268  0.042545

# %%
pca_result = c02_PCA.fit_transform(df.values)
pca_result
# Out:
# array([[-16.862898 , -10.257859 ,   3.2479188],
#        [-55.171116 ,  -4.1565523,   2.1278105],
#        [ 43.14022  , -18.767479 ,  -8.321957 ],
#        ...,
#        [100.23963  ,  -3.5733416, -21.024282 ],
#        [ 50.168213 ,  11.888817 , -14.141736 ],
#        [ 50.527473 ,  12.220439 , -18.426212 ]], dtype=float32)

# %%
df['pca-one'] = pca_result[:,0]
df['pca-two'] = pca_result[:,1]
df['pca-three'] = pca_result[:,2]
df["y"] = is_of_interest_array
df
# Out:
# rid                                           10       100      1000  \
# cid
# ABY001_A375_XH:BRD-K19687926:0.625:24  -0.228962 -0.331568 -0.229186
# ABY001_A375_XH:BRD-K19687926:0.625:3   -0.669595 -0.384668  0.674206
# ABY001_A375_XH:BRD-K19687926:10:24      1.244192  0.540987 -0.331108
# ABY001_A375_XH:BRD-K19687926:10:3       0.259463  0.050904  1.141743
# ABY001_A375_XH:BRD-K19687926:2.5:24     0.429207 -0.633371 -0.633066
# ...                                          ...       ...       ...
# TSAI001_APP11NPC1_XH:BRD-K81418486:2.5  1.064952  1.057685 -0.423703
# TSAI001_ND347327_XH:BRD-K81418486:2.5   0.346960  1.700166 -1.116897
# TSAI001_SAD11NPC4_XH:BRD-K81418486:2.5  1.643360  1.448630 -3.266874
# TSAI001_SAD21NPC2_XH:BRD-K81418486:2.5  1.480882  1.908292 -2.041822
# TSAI001_SB1NPC3_XH:BRD-K81418486:2.5   -0.050354  0.183900 -1.234355
#
# rid                                        10000     10001     10003  \
# cid
# ABY001_A375_XH:BRD-K19687926:0.625:24   0.196661  0.048434 -0.215881
# ABY001_A375_XH:BRD-K19687926:0.625:3   -0.910629 -0.139324  0.664474
# ABY001_A375_XH:BRD-K19687926:10:24     -1.019858 -1.025045  1.120752
# ABY001_A375_XH:BRD-K19687926:10:3       0.416739 -0.251734 -0.697146
# ABY001_A375_XH:BRD-K19687926:2.5:24    -0.246884  0.368670  0.063852
# ...                                          ...       ...       ...
# TSAI001_APP11NPC1_XH:BRD-K81418486:2.5 -0.182850 -0.587905  0.059945
# TSAI001_ND347327_XH:BRD-K81418486:2.5   0.135789  0.686745  0.705168
# TSAI001_SAD11NPC4_XH:BRD-K81418486:2.5 -0.754537 -0.495905  0.266581
# TSAI001_SAD21NPC2_XH:BRD-K81418486:2.5  0.196110  0.113445 -0.010518
# TSAI001_SB1NPC3_XH:BRD-K81418486:2.5   -0.767452  0.037302  1.607037
#
# rid                                        10004     10005     10006  \
# cid
# ABY001_A375_XH:BRD-K19687926:0.625:24   0.113454 -0.108889 -1.175369
# ABY001_A375_XH:BRD-K19687926:0.625:3    0.207748 -0.256744  0.029963
# ABY001_A375_XH:BRD-K19687926:10:24      0.136119 -0.724501 -0.497458
# ABY001_A375_XH:BRD-K19687926:10:3       0.190578  1.203859 -0.220841
# ABY001_A375_XH:BRD-K19687926:2.5:24    -0.557765  0.247735 -0.287608
# ...                                          ...       ...       ...
# TSAI001_APP11NPC1_XH:BRD-K81418486:2.5  0.347273  1.077821  0.019112
# TSAI001_ND347327_XH:BRD-K81418486:2.5   1.463035  0.244165  0.114279
# TSAI001_SAD11NPC4_XH:BRD-K81418486:2.5  0.585351  100.239632  -3.573342
# TSAI001_SAD21NPC2_XH:BRD-K81418486:2.5 -0.019044   50.168213  11.888817
# TSAI001_SB1NPC3_XH:BRD-K81418486:2.5    0.013665   50.527473  12.220439
#
# rid                                     pca-three    y
# cid
# ABY001_A375_XH:BRD-K19687926:0.625:24    3.247919  0.0
# ABY001_A375_XH:BRD-K19687926:0.625:3     2.127810  0.0
# ABY001_A375_XH:BRD-K19687926:10:24      -8.321957  0.0
# ABY001_A375_XH:BRD-K19687926:10:3        3.406626  0.0
# ABY001_A375_XH:BRD-K19687926:2.5:24      3.927614  0.0
# ...                                           ...  ...
# TSAI001_APP11NPC1_XH:BRD-K81418486:2.5 -20.043213  0.0
# TSAI001_ND347327_XH:BRD-K81418486:2.5  -22.522982  0.0
# TSAI001_SAD11NPC4_XH:BRD-K81418486:2.5 -21.024282  0.0
# TSAI001_SAD21NPC2_XH:BRD-K81418486:2.5 -14.141736  0.0
# TSAI001_SB1NPC3_XH:BRD-K81418486:2.5   -18.426212  0.0
#
# [50880 rows x 12332 columns]

# %% [markdown]
# Plotting variation of each principle component

# %%
plt.figure(figsize=(16,10))
sns.scatterplot(
    x="pca-one", y="pca-two",
    hue="y",
    palette=sns.color_palette("hls", 2),
    data=df,
    legend="full",
    alpha=0.3,
).set(title = "L01 All Genes 2d PCA")

ax = plt.figure(figsize=(16,10)).gca(projection='3d')
ax.scatter(
    xs=df["pca-one"],
    ys=df["pca-two"],
    zs=df["pca-three"],
    c=df["y"],
    cmap='tab10'
)
ax.set_xlabel('pca-one')
ax.set_ylabel('pca-two')
ax.set_zlabel('pca-three')

plt.show()

# %% [markdown]
# # t-SNE

# %%
from sklearn.manifold import TSNE

# %%
pca_50 = PCA(n_components=50)
pca_result_50 = pca_50.fit_transform(df_copy.values)
print(pca_result_50.shape)

print('Cumulative explained variation for 50 principal components: {}'.format(np.sum(pca_50.explained_variance_ratio_)))
# Out:
# (50880, 50)
# Cumulative explained variation for 50 principal components: 0.6090942025184631

# %%
time_start = time.time()
tsne = TSNE(n_components=2, verbose=1, perplexity=50) #, n_iter=5000)
tsne_pca_results = tsne.fit_transform(pca_result_50)
print('t-SNE done! Time elapsed: {} seconds'.format(time.time()-time_start))

df_copy['tsne-pca50-one'] = tsne_pca_results[:,0]
df_copy['tsne-pca50-two'] = tsne_pca_results[:,1]
df_copy["y"] = is_of_interest_array

plt.figure(figsize=(16,10))
sns.scatterplot(
    x="tsne-pca50-one", y="tsne-pca50-two",
    hue="y",
    palette=sns.color_palette("hls", 2),
    data=df_copy,
    legend="full",
    alpha=0.3,
).set(title = "L01 All Genes 2d PCA 5 components t-SNE")
plt.show()
# Out:
# [t-SNE] Computing 151 nearest neighbors...
# [t-SNE] Indexed 50880 samples in 0.004s...
# [t-SNE] Computed neighbors for 50880 samples in 62.303s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 50880
# [t-SNE] Computed conditional probabilities for sample 2000 / 50880
# [t-SNE] Computed conditional probabilities for sample 3000 / 50880
# [t-SNE] Computed conditional probabilities for sample 4000 / 50880
# [t-SNE] Computed conditional probabilities for sample 5000 / 50880
# [t-SNE] Computed conditional probabilities for sample 6000 / 50880
# [t-SNE] Computed conditional probabilities for sample 7000 / 50880
# [t-SNE] Computed conditional probabilities for sample 8000 / 50880
# [t-SNE] Computed conditional probabilities for sample 9000 / 50880
# [t-SNE] Computed conditional probabilities for sample 10000 / 50880
# [t-SNE] Computed conditional probabilities for sample 11000 / 50880
# [t-SNE] Computed conditional probabilities for sample 12000 / 50880
# [t-SNE] Computed conditional probabilities for sample 13000 / 50880
# [t-SNE] Computed conditional probabilities for sample 14000 / 50880
# [t-SNE] Computed conditional probabilities for sample 15000 / 50880
# [t-SNE] Computed conditional probabilities for sample 16000 / 50880
# [t-SNE] Computed conditional probabilities for sample 17000 / 50880
# [t-SNE] Computed conditional probabilities for sample 18000 / 50880
# [t-SNE] Computed conditional probabilities for sample 19000 / 50880
# [t-SNE] Computed conditional probabilities for sample 20000 / 50880
# [t-SNE] Computed conditional probabilities for sample 21000 / 50880
# [t-SNE] Computed conditional probabilities for sample 22000 / 50880
# [t-SNE] Computed conditional probabilities for sample 23000 / 50880
# [t-SNE] Computed conditional probabilities for sample 24000 / 50880
# [t-SNE] Computed conditional probabilities for sample 25000 / 50880
# [t-SNE] Computed conditional probabilities for sample 26000 / 50880
# [t-SNE] Computed conditional probabilities for sample 27000 / 50880
# [t-SNE] Computed conditional probabilities for sample 28000 / 50880
# [t-SNE] Computed conditional probabilities for sample 29000 / 50880
# [t-SNE] Computed conditional probabilities for sample 30000 / 50880
# [t-SNE] Computed conditional probabilities for sample 31000 / 50880
# [t-SNE] Computed conditional probabilities for sample 32000 / 50880
# [t-SNE] Computed conditional probabilities for sample 33000 / 50880
# [t-SNE] Computed conditional probabilities for sample 34000 / 50880
# [t-SNE] Computed conditional probabilities for sample 35000 / 50880
# [t-SNE] Computed conditional probabilities for sample 36000 / 50880
# [t-SNE] Computed conditional probabilities for sample 37000 / 50880
# [t-SNE] Computed conditional probabilities for sample 38000 / 50880
# [t-SNE] Computed conditional probabilities for sample 39000 / 50880
# [t-SNE] Computed conditional probabilities for sample 40000 / 50880
# [t-SNE] Computed conditional probabilities for sample 41000 / 50880
# [t-SNE] Computed conditional probabilities for sample 42000 / 50880
# [t-SNE] Computed conditional probabilities for sample 43000 / 50880
# [t-SNE] Computed conditional probabilities for sample 44000 / 50880
# [t-SNE] Computed conditional probabilities for sample 45000 / 50880
# [t-SNE] Computed conditional probabilities for sample 46000 / 50880
# [t-SNE] Computed conditional probabilities for sample 47000 / 50880
# [t-SNE] Computed conditional probabilities for sample 48000 / 50880
# [t-SNE] Computed conditional probabilities for sample 49000 / 50880
# [t-SNE] Computed conditional probabilities for sample 50000 / 50880
# [t-SNE] Computed conditional probabilities for sample 50880 / 50880
# [t-SNE] Mean sigma: 11.067499
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 101.292297
# [t-SNE] KL divergence after 5000 iterations: 3.459019
# t-SNE done! Time elapsed: 1373.5879981517792 seconds
